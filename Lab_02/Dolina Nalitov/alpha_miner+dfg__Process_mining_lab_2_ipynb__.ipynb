# %%
# Установка библиотеки для Process mining
# !pip install pm4py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pm4py
#   Downloading pm4py-2.7.4-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.4 MB/s eta 0:00:00
# Collecting deprecation (from pm4py)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from pm4py) (0.20.1)
# Collecting intervaltree (from pm4py)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pm4py) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pm4py) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pm4py) (3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.5.3)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.10/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from pm4py) (2022.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.10.1)
# Collecting stringdist (from pm4py)
#   Downloading StringDist-1.0.9.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pm4py) (4.65.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation->pm4py) (23.1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from intervaltree->pm4py) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.16.0)
# Building wheels for collected packages: intervaltree, stringdist
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26099 sha256=f2d4d32b75d3e85c41e33ec09c69bc438e14ad5c562038e8eb76cb2c05a9444b
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
#   Building wheel for stringdist (setup.py) ... done
#   Created wheel for stringdist: filename=StringDist-1.0.9-cp310-cp310-linux_x86_64.whl size=24954 sha256=824b6b5724dcbd4093a6e9087105ec6757af4036bc34a1604574192dc3465d2a
#   Stored in directory: /root/.cache/pip/wheels/79/25/0a/4a0c2c7af31a8b473f6e10e30312396f31ae899722600d7b99
# Successfully built intervaltree stringdist
# Installing collected packages: stringdist, intervaltree, deprecation, pm4py
# Successfully installed deprecation-2.1.0 intervaltree-3.1.0 pm4py-2.7.4 stringdist-1.0.9

# %%
# Импортируем необходимые библиотеки
import pandas as pd
import numpy as np
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
import seaborn as sns
import matplotlib.pyplot as plt

# %%
log_csv = pd.read_csv('https://data.4tu.nl/file/657fb1d6-b4c2-4adc-ba48-ed25bf313025/bd6cfa31-44f8-4542-9bad-f1f70c894728', sep= ";", index_col = "Incident ID")

# %% [markdown]
# **Предобработка данных**

# %%
# Преобразуем тип данных в колонке DateTime в специальных формат даты и времени библиотеки Pandas
log_csv['DateStamp'] = pd.to_datetime(log_csv['DateStamp'])

# %%
log_csv
# Out:
#                       DateStamp IncidentActivity_Number IncidentActivity_Type  \
# Incident ID
# IM0000004   2013-07-01 08:17:17             001A3689763          Reassignment
# IM0000004   2013-04-11 13:41:30             001A5852941          Reassignment
# IM0000004   2013-04-11 13:41:30             001A5852943  Update from customer
# IM0000004   2013-04-11 12:09:37             001A5849980       Operator Update
# IM0000004   2013-04-11 12:09:37             001A5849979            Assignment
# ...                         ...                     ...                   ...
# IM0047056   2014-03-31 15:42:37             001A6917801                Closed
# IM0047057   2014-03-31 17:24:50             001A6919138                  Open
# IM0047057   2014-03-31 17:25:07             001A6919139                Update
# IM0047057   2014-03-31 22:47:33             001A6922086                Closed
# IM0047057   2014-03-31 20:38:58             001A6919208            Assignment
#
#             Assignment Group  KM number Interaction ID
# Incident ID
# IM0000004           TEAM0001  KM0000553      SD0000007
# IM0000004           TEAM0002  KM0000553      SD0000007
# IM0000004           TEAM0002  KM0000553      SD0000007
# IM0000004           TEAM0003  KM0000553      SD0000007
# IM0000004           TEAM0003  KM0000553      SD0000007
# ...                      ...        ...            ...
# IM0047056           TEAM0191  KM0001287      SD0146986
# IM0047057           TEAM0199  KM0000182      SD0147088
# IM0047057           TEAM0199  KM0000182      SD0147088
# IM0047057           TEAM0134  KM0000182      SD0147088
# IM0047057           TEAM0134  KM0000182      SD0147088
#
# [466737 rows x 6 columns]

# %%
# Создаем сгруппированную таблицу с начальной отметкой времени и конечной для каждого case
case_starts_ends = log_csv.pivot_table(index='Incident ID', aggfunc={'DateStamp': ['min', 'max']}) 

case_starts_ends = case_starts_ends.reset_index()
case_starts_ends.columns = ['Incident ID', 'caseend', 'casestart'] 
# Merge with the main event log data so that for each row we have the start and end times.
log_csv = log_csv.merge(case_starts_ends, on='Incident ID') 
# Calculate the relative time by subtracting the process start time from the event timestamp
log_csv['relativetime'] = log_csv['DateStamp'] - log_csv['casestart']

log_csv['relativetime_s'] = log_csv['relativetime'].dt.seconds + 86400*log_csv['relativetime'].dt.days 

log_csv['relativedays'] = log_csv['relativetime'].dt.days

log_csv['caselength'] = log_csv['caseend'] - log_csv['casestart']

log_csv
# Out:
#        Incident ID           DateStamp IncidentActivity_Number  \
# 0        IM0000004 2013-07-01 08:17:17             001A3689763
# 1        IM0000004 2013-04-11 13:41:30             001A5852941
# 2        IM0000004 2013-04-11 13:41:30             001A5852943
# 3        IM0000004 2013-04-11 12:09:37             001A5849980
# 4        IM0000004 2013-04-11 12:09:37             001A5849979
# ...            ...                 ...                     ...
# 466732   IM0047056 2014-03-31 15:42:37             001A6917801
# 466733   IM0047057 2014-03-31 17:24:50             001A6919138
# 466734   IM0047057 2014-03-31 17:25:07             001A6919139
# 466735   IM0047057 2014-03-31 22:47:33             001A6922086
# 466736   IM0047057 2014-03-31 20:38:58             001A6919208
#
#        IncidentActivity_Type Assignment Group  KM number Interaction ID  \
# 0               Reassignment         TEAM0001  KM0000553      SD0000007
# 1               Reassignment         TEAM0002  KM0000553      SD0000007
# 2       Update from customer         TEAM0002  KM0000553      SD0000007
# 3            Operator Update         TEAM0003  KM0000553      SD0000007
# 4                 Assignment         TEAM0003  KM0000553      SD0000007
# ...                      ...              ...        ...            ...
# 466732                Closed         TEAM0191  KM0001287      SD0146986
# 466733                  Open         TEAM0199  KM0000182      SD0147088
# 466734                Update         TEAM0199  KM0000182      SD0147088
# 466735                Closed         TEAM0134  KM0000182      SD0147088
# 466736            Assignment         TEAM0134  KM0000182      SD0147088
#
#                    caseend           casestart     relativetime  \
# 0      2013-09-25 08:27:40 2013-04-11 12:09:37 80 days 20:07:40
# 1      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 01:31:53
# 2      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 01:31:53
# 3      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 00:00:00
# 4      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 00:00:00
# ...                    ...                 ...              ...
# 466732 2014-03-31 15:42:37 2014-03-31 15:35:36  0 days 00:07:01
# 466733 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 00:00:00
# 466734 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 00:00:17
# 466735 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 05:22:43
# 466736 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 03:14:08
#
#         relativetime_s  relativedays        caselength
# 0              6984460            80 166 days 20:18:03
# 1                 5513             0 166 days 20:18:03
# 2                 5513             0 166 days 20:18:03
# 3                    0             0 166 days 20:18:03
# 4                    0             0 166 days 20:18:03
# ...                ...           ...               ...
# 466732             421             0   0 days 00:07:01
# 466733               0             0   0 days 05:22:43
# 466734              17             0   0 days 05:22:43
# 466735           19363             0   0 days 05:22:43
# 466736           11648             0   0 days 05:22:43
#
# [466737 rows x 13 columns]

# %%
#количество инцидентов

len(log_csv['Incident ID'].unique())
# Out:
# 46616

# %%
# Переименуем колонки в соответсвии с требованиями Process mining
log_csv.rename(columns=
                {'DateStamp': 'time:timestamp',
                 'Incident ID': 'case:concept:name',
                 'IncidentActivity_Type': 'concept:name',
                 'Assignment Group': 'org:resource'},
                inplace=True)

log_csv
# Out:
#        case:concept:name      time:timestamp IncidentActivity_Number  \
# 0              IM0000004 2013-07-01 08:17:17             001A3689763
# 1              IM0000004 2013-04-11 13:41:30             001A5852941
# 2              IM0000004 2013-04-11 13:41:30             001A5852943
# 3              IM0000004 2013-04-11 12:09:37             001A5849980
# 4              IM0000004 2013-04-11 12:09:37             001A5849979
# ...                  ...                 ...                     ...
# 466732         IM0047056 2014-03-31 15:42:37             001A6917801
# 466733         IM0047057 2014-03-31 17:24:50             001A6919138
# 466734         IM0047057 2014-03-31 17:25:07             001A6919139
# 466735         IM0047057 2014-03-31 22:47:33             001A6922086
# 466736         IM0047057 2014-03-31 20:38:58             001A6919208
#
#                 concept:name org:resource  KM number Interaction ID  \
# 0               Reassignment     TEAM0001  KM0000553      SD0000007
# 1               Reassignment     TEAM0002  KM0000553      SD0000007
# 2       Update from customer     TEAM0002  KM0000553      SD0000007
# 3            Operator Update     TEAM0003  KM0000553      SD0000007
# 4                 Assignment     TEAM0003  KM0000553      SD0000007
# ...                      ...          ...        ...            ...
# 466732                Closed     TEAM0191  KM0001287      SD0146986
# 466733                  Open     TEAM0199  KM0000182      SD0147088
# 466734                Update     TEAM0199  KM0000182      SD0147088
# 466735                Closed     TEAM0134  KM0000182      SD0147088
# 466736            Assignment     TEAM0134  KM0000182      SD0147088
#
#                    caseend           casestart     relativetime  \
# 0      2013-09-25 08:27:40 2013-04-11 12:09:37 80 days 20:07:40
# 1      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 01:31:53
# 2      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 01:31:53
# 3      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 00:00:00
# 4      2013-09-25 08:27:40 2013-04-11 12:09:37  0 days 00:00:00
# ...                    ...                 ...              ...
# 466732 2014-03-31 15:42:37 2014-03-31 15:35:36  0 days 00:07:01
# 466733 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 00:00:00
# 466734 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 00:00:17
# 466735 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 05:22:43
# 466736 2014-03-31 22:47:33 2014-03-31 17:24:50  0 days 03:14:08
#
#         relativetime_s  relativedays        caselength
# 0              6984460            80 166 days 20:18:03
# 1                 5513             0 166 days 20:18:03
# 2                 5513             0 166 days 20:18:03
# 3                    0             0 166 days 20:18:03
# 4                    0             0 166 days 20:18:03
# ...                ...           ...               ...
# 466732             421             0   0 days 00:07:01
# 466733               0             0   0 days 05:22:43
# 466734              17             0   0 days 05:22:43
# 466735           19363             0   0 days 05:22:43
# 466736           11648             0   0 days 05:22:43
#
# [466737 rows x 13 columns]

# %%
# введем задержку в 0,1 секунды в действии "Закрыто", так чтобы оно всегда происходило после действия "Вызвано CI".
import datetime

delta = pd.Timedelta(seconds=0.1)

# Filter the rows where 'concept:name' is 'Closed' and update 'time:timestamp'
log_csv.loc[log_csv['concept:name'] == 'Closed', 'time:timestamp'] += delta

# %%
# удалим из журнала событий незакрытые кейсы

# Filter the incidents where 'concept:name' is equal to 'Closed'
closed_incidents = log_csv[log_csv['concept:name'] == 'Closed']['case:concept:name'].unique()

# Filter and keep only the incidents with 'concept:name' equal to 'Closed'
log_csv = log_csv[log_csv['case:concept:name'].isin(closed_incidents)]

# %%
incident_events = pd.crosstab(log_csv['case:concept:name'], log_csv['concept:name']) 
incident_events.sum()
# Out:
# concept:name
# Affected CI Change                184
# Analysis/Research                 981
# Assignment                      88247
# Callback Request                   53
# Caused By CI                    34382
# Closed                          50145
# Communication with customer      6142
# Communication with vendor        1737
# Contact Change                     32
# Description Update               4470
# Dial-in                             2
# External Vendor Assignment       3842
# External Vendor Reassignment       33
# External update                  1099
# Impact Change                    1276
# Incident reproduction              23
# Mail to Customer                 3788
# Notify By Change                  281
# OO Response                        33
# Open                            46158
# Operator Update                 56149
# Pending vendor                   3842
# Problem Closure                    40
# Problem Workaround                140
# Quality Indicator                2465
# Quality Indicator Fixed          7791
# Quality Indicator Set            1956
# Reassignment                    51870
# Referred                           29
# Reopen                           2428
# Resolved                         1626
# Service Change                    159
# Status Change                   50322
# Update                          35945
# Update from customer             3900
# Urgency Change                   1310
# Vendor Reference                  656
# Vendor Reference Change           128
# alert stage 1                     113
# dtype: int64

# %%
incident_events.sum(axis=1).sort_values()
# Out:
# case:concept:name
# IM0000033      1
# IM0038821      2
# IM0038846      2
# IM0038823      2
# IM0038726      2
#             ...
# IM0005897    165
# IM0000220    170
# IM0004038    171
# IM0000382    175
# IM0000428    178
# Length: 46167, dtype: int64

# %%
log_csv[log_csv['case:concept:name'] == 'IM0000033']
# Out:
#     case:concept:name          time:timestamp IncidentActivity_Number  \
# 241         IM0000033 2013-11-30 10:39:10.100             001A6062488
#
#     concept:name org:resource  KM number Interaction ID             caseend  \
# 241       Closed     TEAM0008  KM0001430      SD0000056 2013-11-30 10:39:10
#
#               casestart relativetime  relativetime_s  relativedays caselength
# 241 2013-11-30 10:39:10       0 days               0             0     0 days

# %%
log_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463777 entries, 0 to 466736
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case:concept:name        463777 non-null  object
#  1   time:timestamp           463777 non-null  datetime64[ns]
#  2   IncidentActivity_Number  463777 non-null  object
#  3   concept:name             463777 non-null  object
#  4   org:resource             463777 non-null  object
#  5   KM number                463777 non-null  object
#  6   Interaction ID           463777 non-null  object
#  7   caseend                  463777 non-null  datetime64[ns]
#  8   casestart                463777 non-null  datetime64[ns]
#  9   relativetime             463777 non-null  timedelta64[ns]
#  10  relativetime_s           463777 non-null  int64
#  11  relativedays             463777 non-null  int64
#  12  caselength               463777 non-null  timedelta64[ns]
# dtypes: datetime64[ns](3), int64(2), object(6), timedelta64[ns](2)
# memory usage: 49.5+ MB

# %% [markdown]
# **Process mining**

# %%
# Преобразуем DataFrame в формат журнала Process mining
event_log = log_converter.apply(log_csv)

# %%
# Количество различных событий в нашем журнале событий

len(log_csv)
# Out:
# 463777

# %%
# Количество всех кейсов в нашем журнале событий

len(event_log)
# Out:
# 46167

# %%
from pm4py.algo.filtering.log.attributes import attributes_filter

activities_teams = attributes_filter.get_attribute_values(log_csv, "org:resource")

dict(sorted(activities_teams.items(),  key=lambda item: item[1]))
# Out:
# {'TEAM0164': 1,
#  'TEAM0168': 1,
#  'TEAM0169': 1,
#  'TEAM0238': 1,
#  'TEAM0006': 2,
#  'TEAM0158': 2,
#  'TEAM0159': 2,
#  'TEAM0161': 2,
#  'TEAM0236': 2,
#  'TEAM0156': 3,
#  'TEAM0026': 4,
#  'TEAM0084': 4,
#  'TEAM0116': 4,
#  'TEAM0160': 4,
#  'TEAM0229': 4,
#  'TEAM0231': 4,
#  'TEAM0232': 4,
#  'TEAM0234': 4,
#  'TEAM0235': 4,
#  'TEAM0240': 4,
#  'TEAM0144': 5,
#  'TEAM0157': 5,
#  'TEAM0230': 5,
#  'TEAM0083': 6,
#  'TEAM0177': 6,
#  'TEAM0233': 6,
#  'TEAM0142': 7,
#  'TEAM0150': 7,
#  'TEAM0241': 7,
#  'TEAM0146': 8,
#  'TEAM0149': 8,
#  'TEAM0220': 8,
#  'TEAM0223': 8,
#  'TEAM0098': 9,
#  'TEAM0153': 9,
#  'TEAM0228': 10,
#  'TEAM0140': 11,
#  'TEAM0237': 12,
#  'TEAM0117': 13,
#  'TEAM0206': 13,
#  'TEAM0103': 14,
#  'TEAM0178': 15,
#  'TEAM0067': 16,
#  'TEAM0145': 16,
#  'TEAM0239': 16,
#  'TEAM0183': 19,
#  'TEAM0163': 20,
#  'TEAM0130': 23,
#  'TEAM0196': 25,
#  'TEAM0118': 28,
#  'TEAM0226': 29,
#  'TEAM0225': 30,
#  'TEAM0090': 32,
#  'TEAM0162': 32,
#  'TEAM0062': 33,
#  'TEAM0167': 33,
#  'TEAM0194': 34,
#  'TEAM0055': 37,
#  'TEAM0096': 39,
#  'TEAM0089': 41,
#  'TEAM0120': 41,
#  'TEAM0148': 46,
#  'TEAM0030': 47,
#  'TEAM0073': 49,
#  'TEAM0137': 49,
#  'TEAM0114': 51,
#  'TEAM0154': 52,
#  'TEAM0195': 53,
#  'TEAM0200': 56,
#  'TEAM0151': 60,
#  'TEAM0152': 61,
#  'TEAM0204': 62,
#  'TEAM0218': 62,
#  'TEAM0061': 63,
#  'TEAM0227': 63,
#  'TEAM0022': 65,
#  'TEAM0224': 65,
#  'TEAM0012': 68,
#  'TEAM0141': 68,
#  'TEAM0219': 73,
#  'TEAM0099': 76,
#  'TEAM0011': 77,
#  'TEAM0147': 78,
#  'TEAM0165': 80,
#  'TEAM0068': 83,
#  'TEAM0139': 87,
#  'TEAM0221': 87,
#  'TEAM0082': 88,
#  'TEAM0110': 91,
#  'TEAM0060': 92,
#  'TEAM0222': 92,
#  'TEAM0133': 94,
#  'TEAM0211': 94,
#  'TEAM0136': 97,
#  'TEAM0138': 99,
#  'TEAM0122': 101,
#  'TEAM0095': 112,
#  'TEAM0005': 115,
#  'TEAM0106': 118,
#  'TEAM0216': 118,
#  'TEAM0072': 126,
#  'TEAM0125': 127,
#  'TEAM0080': 131,
#  'TEAM0079': 132,
#  'TEAM0115': 137,
#  'TEAM0214': 143,
#  'TEAM0107': 145,
#  'TEAM0129': 149,
#  'TEAM0009': 152,
#  'TEAM0109': 159,
#  'TEAM0088': 164,
#  'TEAM0174': 169,
#  'TEAM0081': 177,
#  'TEAM0135': 183,
#  'TEAM0112': 191,
#  'TEAM0100': 195,
#  'TEAM0036': 198,
#  'TEAM0182': 221,
#  'TEAM0202': 243,
#  'TEAM0064': 260,
#  'TEAM0184': 273,
#  'TEAM0209': 286,
#  'TEAM0189': 307,
#  'TEAM0193': 315,
#  'TEAM0201': 323,
#  'TEAM0213': 333,
#  'TEAM0124': 335,
#  'TEAM0097': 340,
#  'TEAM0126': 363,
#  'TEAM0170': 370,
#  'TEAM0131': 374,
#  'TEAM0078': 381,
#  'TEAM0029': 383,
#  'TEAM0032': 385,
#  'TEAM0121': 420,
#  'TEAM0155': 423,
#  'TEAM0217': 439,
#  'TEAM0077': 450,
#  'TEAM0212': 470,
#  'TEAM0208': 482,
#  'TEAM0111': 485,
#  'TEAM0203': 535,
#  'TEAM0054': 543,
#  'TEAM0128': 547,
#  'TEAM0056': 593,
#  'TEAM0074': 617,
#  'TEAM0037': 634,
#  'TEAM0071': 642,
#  'TEAM0091': 642,
#  'TEAM0215': 664,
#  'TEAM0210': 679,
#  'TEAM0043': 694,
#  'TEAM0059': 724,
#  'TEAM0185': 756,
#  'TEAM0101': 765,
#  'TEAM0172': 784,
#  'TEAM0180': 848,
#  'TEAM0038': 851,
#  'TEAM0047': 875,
#  'TEAM0113': 877,
#  'TEAM0085': 890,
#  'TEAM0143': 897,
#  'TEAM0207': 988,
#  'TEAM0004': 1002,
#  'TEAM0198': 1012,
#  'TEAM0104': 1025,
#  'TEAM0076': 1028,
#  'TEAM0094': 1030,
#  'TEAM0108': 1065,
#  'TEAM0058': 1087,
#  'TEAM0050': 1088,
#  'TEAM0175': 1094,
#  'TEAM0020': 1133,
#  'TEAM0173': 1162,
#  'TEAM0051': 1205,
#  'TEAM0024': 1312,
#  'TEAM0046': 1323,
#  'TEAM0028': 1365,
#  'TEAM0166': 1378,
#  'TEAM0027': 1392,
#  'TEAM0053': 1431,
#  'TEAM0042': 1454,
#  'TEAM0065': 1557,
#  'TEAM0179': 1572,
#  'TEAM0041': 1615,
#  'TEAM0035': 1768,
#  'TEAM0025': 1803,
#  'TEAM0123': 1817,
#  'TEAM0186': 1900,
#  'TEAM0048': 1906,
#  'TEAM0066': 1907,
#  'TEAM0070': 1956,
#  'TEAM0093': 1964,
#  'TEAM0134': 1985,
#  'TEAM0119': 2024,
#  'TEAM0127': 2098,
#  'TEAM0033': 2248,
#  'TEAM0188': 2385,
#  'TEAM0199': 2434,
#  'TEAM0105': 2598,
#  'TEAM0021': 2652,
#  'TEAM0034': 2841,
#  'TEAM0087': 2867,
#  'TEAM0040': 2878,
#  'TEAM0019': 2965,
#  'TEAM0092': 3071,
#  'TEAM0205': 3101,
#  'TEAM0132': 3185,
#  'TEAM0045': 3311,
#  'TEAM0102': 3522,
#  'TEAM0052': 3574,
#  'TEAM0001': 3777,
#  'TEAM0192': 3795,
#  'TEAM0063': 3967,
#  'TEAM0013': 4490,
#  'TEAM0049': 4605,
#  'TEAM0190': 4759,
#  'TEAM0044': 4830,
#  'TEAM0010': 5043,
#  'TEAM0171': 5260,
#  'TEAM0176': 5359,
#  'TEAM0057': 5462,
#  'TEAM0187': 5922,
#  'TEAM0197': 6069,
#  'TEAM0014': 6414,
#  'TEAM0017': 6643,
#  'TEAM0002': 6694,
#  'TEAM0069': 7151,
#  'TEAM9999': 8246,
#  'TEAM0181': 8538,
#  'TEAM0016': 9096,
#  'TEAM0003': 10047,
#  'TEAM0075': 11255,
#  'TEAM0015': 11964,
#  'TEAM0191': 11998,
#  'TEAM0086': 13515,
#  'TEAM0023': 15190,
#  'TEAM0007': 15864,
#  'TEAM0031': 16414,
#  'TEAM0018': 17368,
#  'TEAM0039': 19199,
#  'TEAM0008': 81584}

# %%
activities = attributes_filter.get_attribute_values(log_csv, 'concept:name')
activities
# Out:
# {'Reassignment': 51870,
#  'Update from customer': 3900,
#  'Operator Update': 56149,
#  'Assignment': 88247,
#  'Closed': 50145,
#  'Caused By CI': 34382,
#  'Update': 35945,
#  'Status Change': 50322,
#  'Description Update': 4470,
#  'Analysis/Research': 981,
#  'Resolved': 1626,
#  'Reopen': 2428,
#  'OO Response': 33,
#  'Communication with customer': 6142,
#  'External Vendor Assignment': 3842,
#  'Pending vendor': 3842,
#  'Open': 46158,
#  'Communication with vendor': 1737,
#  'Vendor Reference': 656,
#  'Urgency Change': 1310,
#  'Impact Change': 1276,
#  'Quality Indicator Fixed': 7791,
#  'Problem Workaround': 140,
#  'Problem Closure': 40,
#  'Service Change': 159,
#  'Affected CI Change': 184,
#  'Referred': 29,
#  'Vendor Reference Change': 128,
#  'Incident reproduction': 23,
#  'Quality Indicator': 2465,
#  'Notify By Change': 281,
#  'Contact Change': 32,
#  'Mail to Customer': 3788,
#  'Quality Indicator Set': 1956,
#  'Callback Request': 53,
#  'External update': 1099,
#  'External Vendor Reassignment': 33,
#  'alert stage 1': 113,
#  'Dial-in': 2}

# %%
from pm4py.algo.filtering.log.variants import variants_filter
from pm4py.statistics.traces.generic.log import case_statistics

variants = variants_filter.get_variants(event_log)
print(f"У нас есть: {len(variants)} различных вариантов путей в нашем журнале событий")
# Out:
# У нас есть: 31389 различных вариантов путей в нашем журнале событий

# %%
variants_count = case_statistics.get_variant_statistics(log_csv)

variants_count
# Out:
# [{'variant': ('Open', 'Closed', 'Caused By CI'), 'count': 716},
#  {'variant': ('Closed', 'Caused By CI', 'Open'), 'count': 681},
#  {'variant': ('Caused By CI', 'Closed', 'Open'), 'count': 675},
#  {'variant': ('Open', 'Caused By CI', 'Closed'), 'count': 647},
#  {'variant': ('Caused By CI', 'Open', 'Closed'), 'count': 352},
#  {'variant': ('Closed', 'Open', 'Caused By CI'), 'count': 323},
#  {'variant': ('Caused By CI', 'Closed', 'Assignment', 'Open'), 'count': 147},
#  {'variant': ('Closed', 'Caused By CI', 'Assignment', 'Open'), 'count': 138},
#  {'variant': ('Open', 'Assignment', 'Caused By CI', 'Closed'), 'count': 130},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Assignment'), 'count': 128},
#  {'variant': ('Open', 'Assignment', 'Closed', 'Caused By CI'), 'count': 125},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Assignment'), 'count': 124},
#  {'variant': ('Assignment', 'Closed', 'Caused By CI', 'Open'), 'count': 121},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Assignment'), 'count': 119},
#  {'variant': ('Open', 'Closed', 'Caused By CI', 'Assignment'), 'count': 116},
#  {'variant': ('Assignment', 'Open', 'Closed', 'Caused By CI'), 'count': 113},
#  {'variant': ('Assignment', 'Caused By CI', 'Closed', 'Open'), 'count': 104},
#  {'variant': ('Assignment', 'Open', 'Caused By CI', 'Closed'), 'count': 98},
#  {'variant': ('Closed', 'Assignment', 'Caused By CI', 'Open'), 'count': 75},
#  {'variant': ('Open', 'Closed', 'Assignment', 'Caused By CI'), 'count': 65},
#  {'variant': ('Caused By CI', 'Assignment', 'Closed', 'Open'), 'count': 61},
#  {'variant': ('Open', 'Caused By CI', 'Assignment', 'Closed'), 'count': 60},
#  {'variant': ('Assignment', 'Closed', 'Open', 'Caused By CI'), 'count': 60},
#  {'variant': ('Closed', 'Open', 'Caused By CI', 'Assignment'), 'count': 59},
#  {'variant': ('Open', 'Status Change', 'Assignment', 'Closed', 'Caused By CI'),
#   'count': 55},
#  {'variant': ('Caused By CI', 'Open', 'Closed', 'Assignment'), 'count': 54},
#  {'variant': ('Closed', 'Update', 'Open'), 'count': 53},
#  {'variant': ('Open', 'Status Change', 'Assignment', 'Caused By CI', 'Closed'),
#   'count': 51},
#  {'variant': ('Closed', 'Caused By CI', 'Assignment', 'Open', 'Status Change'),
#   'count': 50},
#  {'variant': ('Closed', 'Caused By CI', 'Assignment', 'Status Change', 'Open'),
#   'count': 49},
#  {'variant': ('Caused By CI', 'Closed', 'Assignment', 'Status Change', 'Open'),
#   'count': 49},
#  {'variant': ('Assignment', 'Status Change', 'Caused By CI', 'Closed', 'Open'),
#   'count': 49},
#  {'variant': ('Quality Indicator Fixed', 'Caused By CI', 'Closed', 'Open'),
#   'count': 48},
#  {'variant': ('Caused By CI', 'Closed', 'Status Change', 'Assignment', 'Open'),
#   'count': 48},
#  {'variant': ('Assignment', 'Closed', 'Caused By CI', 'Status Change', 'Open'),
#   'count': 48},
#  {'variant': ('Closed', 'Caused By CI', 'Status Change', 'Assignment', 'Open'),
#   'count': 47},
#  {'variant': ('Open', 'Closed', 'Caused By CI', 'Status Change', 'Assignment'),
#   'count': 46},
#  {'variant': ('Open', 'Assignment', 'Status Change', 'Closed', 'Caused By CI'),
#   'count': 45},
#  {'variant': ('Closed', 'Open', 'Update'), 'count': 45},
#  {'variant': ('Assignment', 'Status Change', 'Open', 'Caused By CI', 'Closed'),
#   'count': 45},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Status Change', 'Assignment'),
#   'count': 44},
#  {'variant': ('Caused By CI', 'Open', 'Assignment', 'Closed'), 'count': 44},
#  {'variant': ('Assignment', 'Status Change', 'Closed', 'Caused By CI', 'Open'),
#   'count': 44},
#  {'variant': ('Open', 'Assignment', 'Status Change', 'Caused By CI', 'Closed'),
#   'count': 43},
#  {'variant': ('Open', 'Status Change', 'Caused By CI', 'Closed', 'Assignment'),
#   'count': 41},
#  {'variant': ('Open', 'Quality Indicator Fixed', 'Caused By CI', 'Closed'),
#   'count': 41},
#  {'variant': ('Open', 'Closed', 'Caused By CI', 'Quality Indicator Fixed'),
#   'count': 41},
#  {'variant': ('Open', 'Update', 'Closed'), 'count': 39},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Status Change', 'Assignment'),
#   'count': 39},
#  {'variant': ('Assignment', 'Caused By CI', 'Open', 'Closed'), 'count': 39},
#  {'variant': ('Assignment', 'Caused By CI', 'Closed', 'Status Change', 'Open'),
#   'count': 38},
#  {'variant': ('Status Change', 'Open', 'Closed', 'Caused By CI', 'Assignment'),
#   'count': 37},
#  {'variant': ('Status Change', 'Assignment', 'Open', 'Closed', 'Caused By CI'),
#   'count': 37},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Assignment', 'Status Change'),
#   'count': 36},
#  {'variant': ('Closed', 'Caused By CI', 'Quality Indicator Fixed', 'Open'),
#   'count': 36},
#  {'variant': ('Caused By CI', 'Closed', 'Assignment', 'Open', 'Status Change'),
#   'count': 36},
#  {'variant': ('Update', 'Open', 'Closed'), 'count': 35},
#  {'variant': ('Open', 'Closed', 'Caused By CI', 'Assignment', 'Status Change'),
#   'count': 35},
#  {'variant': ('Status Change', 'Open', 'Assignment', 'Caused By CI', 'Closed'),
#   'count': 34},
#  {'variant': ('Quality Indicator Fixed', 'Closed', 'Caused By CI', 'Open'),
#   'count': 34},
#  {'variant': ('Open', 'Status Change', 'Closed', 'Caused By CI', 'Assignment'),
#   'count': 34},
#  {'variant': ('Open', 'Quality Indicator Fixed', 'Closed', 'Caused By CI'),
#   'count': 34},
#  {'variant': ('Caused By CI', 'Closed', 'Status Change', 'Open', 'Assignment'),
#   'count': 34},
#  {'variant': ('Assignment', 'Status Change', 'Open', 'Closed', 'Caused By CI'),
#   'count': 34},
#  {'variant': ('Assignment', 'Closed', 'Caused By CI', 'Open', 'Status Change'),
#   'count': 34},
#  {'variant': ('Status Change', 'Caused By CI', 'Closed', 'Open', 'Assignment'),
#   'count': 33},
#  {'variant': ('Closed', 'Open', 'Assignment', 'Caused By CI'), 'count': 33},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Assignment', 'Status Change'),
#   'count': 33},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Quality Indicator Fixed'),
#   'count': 32},
#  {'variant': ('Status Change', 'Open', 'Assignment', 'Closed', 'Caused By CI'),
#   'count': 31},
#  {'variant': ('Status Change', 'Closed', 'Caused By CI', 'Assignment', 'Open'),
#   'count': 31},
#  {'variant': ('Open', 'Assignment', 'Caused By CI', 'Closed', 'Status Change'),
#   'count': 31},
#  {'variant': ('Closed', 'Quality Indicator Fixed', 'Caused By CI', 'Open'),
#   'count': 31},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Quality Indicator Fixed'),
#   'count': 31},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Status Change', 'Assignment'),
#   'count': 31},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Assignment', 'Status Change'),
#   'count': 31},
#  {'variant': ('Assignment', 'Open', 'Status Change', 'Caused By CI', 'Closed'),
#   'count': 31},
#  {'variant': ('Assignment', 'Open', 'Caused By CI', 'Closed', 'Status Change'),
#   'count': 31},
#  {'variant': ('Status Change', 'Assignment', 'Caused By CI', 'Closed', 'Open'),
#   'count': 30},
#  {'variant': ('Closed', 'Caused By CI', 'Status Change', 'Open', 'Assignment'),
#   'count': 30},
#  {'variant': ('Status Change', 'Closed', 'Caused By CI', 'Open', 'Assignment'),
#   'count': 29},
#  {'variant': ('Resolved', 'Closed', 'Open'), 'count': 29},
#  {'variant': ('Closed', 'Assignment', 'Open', 'Caused By CI'), 'count': 29},
#  {'variant': ('Open', 'Caused By CI', 'Status Change', 'Closed', 'Assignment'),
#   'count': 28},
#  {'variant': ('Caused By CI', 'Assignment', 'Open', 'Closed'), 'count': 28},
#  {'variant': ('Status Change', 'Assignment', 'Closed', 'Caused By CI', 'Open'),
#   'count': 27},
#  {'variant': ('Caused By CI', 'Quality Indicator Fixed', 'Closed', 'Open'),
#   'count': 27},
#  {'variant': ('Status Change', 'Assignment', 'Open', 'Caused By CI', 'Closed'),
#   'count': 26},
#  {'variant': ('Resolved', 'Open', 'Closed'), 'count': 26},
#  {'variant': ('Open', 'Closed', 'Status Change', 'Caused By CI', 'Assignment'),
#   'count': 26},
#  {'variant': ('Open', 'Assignment', 'Closed', 'Caused By CI', 'Status Change'),
#   'count': 26},
#  {'variant': ('Closed', 'Assignment', 'Open'), 'count': 26},
#  {'variant': ('Caused By CI', 'Closed', 'Quality Indicator Fixed', 'Open'),
#   'count': 26},
#  {'variant': ('Caused By CI', 'Assignment', 'Closed', 'Status Change', 'Open'),
#   'count': 26},
#  {'variant': ('Status Change', 'Caused By CI', 'Closed', 'Assignment', 'Open'),
#   'count': 25},
#  {'variant': ('Assignment', 'Open', 'Closed', 'Caused By CI', 'Status Change'),
#   'count': 25},
#  {'variant': ('Assignment', 'Open', 'Closed'), 'count': 25},
#  {'variant': ('Status Change', 'Open', 'Caused By CI', 'Closed', 'Assignment'),
#   'count': 24},
#  {'variant': ('Closed', 'Resolved', 'Open'), 'count': 24},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Quality Indicator Fixed'),
#   'count': 24},
#  {'variant': ('Open', 'Closed', 'Resolved'), 'count': 23},
#  {'variant': ('Open', 'Caused By CI', 'Quality Indicator Fixed', 'Closed'),
#   'count': 23},
#  {'variant': ('Open', 'Assignment', 'Caused By CI', 'Status Change', 'Closed'),
#   'count': 22},
#  {'variant': ('Closed', 'Caused By CI', 'Quality Indicator', 'Open'),
#   'count': 22},
#  {'variant': ('Quality Indicator Fixed', 'Open', 'Caused By CI', 'Closed'),
#   'count': 21},
#  {'variant': ('Open', 'Quality Indicator', 'Caused By CI', 'Closed'),
#   'count': 21},
#  {'variant': ('Closed', 'Open', 'Caused By CI', 'Status Change', 'Assignment'),
#   'count': 21},
#  {'variant': ('Closed', 'Assignment', 'Status Change', 'Caused By CI', 'Open'),
#   'count': 21},
#  {'variant': ('Status Change', 'Open', 'Caused By CI', 'Assignment', 'Closed'),
#   'count': 20},
#  {'variant': ('Status Change', 'Caused By CI', 'Open', 'Closed', 'Assignment'),
#   'count': 20},
#  {'variant': ('Quality Indicator Fixed', 'Caused By CI', 'Open', 'Closed'),
#   'count': 20},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Status Change',
#    'Assignment',
#    'Closed'),
#   'count': 20},
#  {'variant': ('Closed', 'Open', 'Resolved'), 'count': 20},
#  {'variant': ('Caused By CI', 'Status Change', 'Closed', 'Assignment', 'Open'),
#   'count': 20},
#  {'variant': ('Caused By CI', 'Open', 'Closed', 'Status Change', 'Assignment'),
#   'count': 20},
#  {'variant': ('Caused By CI', 'Assignment', 'Status Change', 'Closed', 'Open'),
#   'count': 20},
#  {'variant': ('Assignment', 'Status Change', 'Caused By CI', 'Open', 'Closed'),
#   'count': 20},
#  {'variant': ('Open', 'Caused By CI', 'Status Change', 'Assignment', 'Closed'),
#   'count': 19},
#  {'variant': ('Open', 'Assignment', 'Closed'), 'count': 19},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 19},
#  {'variant': ('Caused By CI', 'Assignment', 'Closed', 'Open', 'Status Change'),
#   'count': 19},
#  {'variant': ('Assignment', 'Status Change', 'Closed', 'Open', 'Caused By CI'),
#   'count': 19},
#  {'variant': ('Quality Indicator Fixed', 'Open', 'Closed', 'Caused By CI'),
#   'count': 18},
#  {'variant': ('Quality Indicator', 'Caused By CI', 'Closed', 'Open'),
#   'count': 18},
#  {'variant': ('Open', 'Closed', 'Status Change', 'Assignment', 'Caused By CI'),
#   'count': 18},
#  {'variant': ('Closed', 'Status Change', 'Caused By CI', 'Assignment', 'Open'),
#   'count': 18},
#  {'variant': ('Caused By CI', 'Status Change', 'Open', 'Closed', 'Assignment'),
#   'count': 18},
#  {'variant': ('Assignment', 'Caused By CI', 'Closed', 'Open', 'Status Change'),
#   'count': 18},
#  {'variant': ('Status Change',
#    'Open',
#    'Closed',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 17},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Mail to Customer'),
#   'count': 17},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 17},
#  {'variant': ('Operator Update', 'Open', 'Caused By CI', 'Closed'),
#   'count': 17},
#  {'variant': ('Open', 'Resolved', 'Closed'), 'count': 17},
#  {'variant': ('Open', 'Closed', 'Quality Indicator Fixed', 'Caused By CI'),
#   'count': 17},
#  {'variant': ('Open', 'Closed', 'Assignment', 'Status Change', 'Caused By CI'),
#   'count': 17},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed'),
#   'count': 17},
#  {'variant': ('Closed', 'Open', 'Assignment'), 'count': 17},
#  {'variant': ('Closed', 'Open'), 'count': 17},
#  {'variant': ('Caused By CI', 'Open', 'Closed', 'Assignment', 'Status Change'),
#   'count': 17},
#  {'variant': ('Assignment', 'Open', 'Status Change', 'Closed', 'Caused By CI'),
#   'count': 17},
#  {'variant': ('Assignment', 'Closed', 'Open'), 'count': 17},
#  {'variant': ('Assignment', 'Caused By CI', 'Status Change', 'Closed', 'Open'),
#   'count': 17},
#  {'variant': ('Status Change',
#    'Closed',
#    'Open',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 16},
#  {'variant': ('Status Change', 'Closed', 'Open', 'Caused By CI', 'Assignment'),
#   'count': 16},
#  {'variant': ('Status Change', 'Caused By CI', 'Assignment', 'Open', 'Closed'),
#   'count': 16},
#  {'variant': ('Open', 'Status Change', 'Closed', 'Assignment', 'Caused By CI'),
#   'count': 16},
#  {'variant': ('Open', 'Closed'), 'count': 16},
#  {'variant': ('Open', 'Caused By CI', 'Assignment', 'Closed', 'Status Change'),
#   'count': 16},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Operator Update'),
#   'count': 16},
#  {'variant': ('Status Change', 'Open', 'Closed', 'Assignment', 'Caused By CI'),
#   'count': 15},
#  {'variant': ('Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 15},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 15},
#  {'variant': ('Open', 'Closed', 'Caused By CI', 'Quality Indicator'),
#   'count': 15},
#  {'variant': ('Mail to Customer',
#    'Closed',
#    'Status Change',
#    'Open',
#    'Assignment'),
#   'count': 15},
#  {'variant': ('Mail to Customer',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Open'),
#   'count': 15},
#  {'variant': ('Closed', 'Caused By CI', 'Operator Update', 'Open'),
#   'count': 15},
#  {'variant': ('Closed', 'Assignment', 'Caused By CI', 'Status Change', 'Open'),
#   'count': 15},
#  {'variant': ('Caused By CI', 'Status Change', 'Closed', 'Open', 'Assignment'),
#   'count': 15},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Assignment',
#    'Open'),
#   'count': 15},
#  {'variant': ('Assignment', 'Caused By CI', 'Status Change', 'Open', 'Closed'),
#   'count': 15},
#  {'variant': ('Status Change', 'Closed', 'Assignment', 'Caused By CI', 'Open'),
#   'count': 14},
#  {'variant': ('Open', 'Closed', 'Assignment'), 'count': 14},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Status Change',
#    'Closed',
#    'Assignment'),
#   'count': 14},
#  {'variant': ('Closed', 'Open', 'Status Change', 'Caused By CI', 'Assignment'),
#   'count': 14},
#  {'variant': ('Assignment', 'Closed', 'Status Change', 'Open', 'Caused By CI'),
#   'count': 14},
#  {'variant': ('Assignment',
#    'Closed',
#    'Open',
#    'Status Change',
#    'Mail to Customer'),
#   'count': 14},
#  {'variant': ('Assignment', 'Closed', 'Open', 'Caused By CI', 'Status Change'),
#   'count': 14},
#  {'variant': ('Status Change',
#    'Open',
#    'Closed',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 13},
#  {'variant': ('Status Change', 'Caused By CI', 'Open', 'Assignment', 'Closed'),
#   'count': 13},
#  {'variant': ('Status Change', 'Assignment', 'Closed', 'Open', 'Caused By CI'),
#   'count': 13},
#  {'variant': ('Open',
#    'Status Change',
#    'Mail to Customer',
#    'Closed',
#    'Assignment'),
#   'count': 13},
#  {'variant': ('Open', 'Status Change', 'Caused By CI', 'Assignment', 'Closed'),
#   'count': 13},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Mail to Customer',
#    'Closed'),
#   'count': 13},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Closed',
#    'Assignment',
#    'Status Change'),
#   'count': 13},
#  {'variant': ('Open', 'Caused By CI', 'Quality Indicator', 'Closed'),
#   'count': 13},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Closed'),
#   'count': 13},
#  {'variant': ('Closed', 'Status Change', 'Caused By CI', 'Open', 'Assignment'),
#   'count': 13},
#  {'variant': ('Closed', 'Open', 'Status Change', 'Assignment', 'Caused By CI'),
#   'count': 13},
#  {'variant': ('Closed', 'Open', 'Quality Indicator Fixed', 'Caused By CI'),
#   'count': 13},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Operator Update',
#    'Assignment'),
#   'count': 13},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Operator Update'),
#   'count': 13},
#  {'variant': ('Closed',
#    'Assignment',
#    'Status Change',
#    'Mail to Customer',
#    'Open'),
#   'count': 13},
#  {'variant': ('Caused By CI', 'Quality Indicator', 'Closed', 'Open'),
#   'count': 13},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Closed',
#    'Quality Indicator',
#    'Open'),
#   'count': 13},
#  {'variant': ('Assignment', 'Closed', 'Open', 'Status Change', 'Caused By CI'),
#   'count': 13},
#  {'variant': ('Status Change', 'Closed', 'Assignment', 'Open', 'Caused By CI'),
#   'count': 12},
#  {'variant': ('Status Change', 'Caused By CI', 'Assignment', 'Closed', 'Open'),
#   'count': 12},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Mail to Customer',
#    'Closed',
#    'Open'),
#   'count': 12},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Open'),
#   'count': 12},
#  {'variant': ('Open',
#    'Status Change',
#    'Closed',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 12},
#  {'variant': ('Open',
#    'Quality Indicator',
#    'Caused By CI',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 12},
#  {'variant': ('Open', 'Operator Update', 'Caused By CI', 'Closed'),
#   'count': 12},
#  {'variant': ('Open',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 12},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Assignment'),
#   'count': 12},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Operator Update',
#    'Caused By CI',
#    'Closed'),
#   'count': 12},
#  {'variant': ('Open',
#    'Assignment',
#    'Operator Update',
#    'Caused By CI',
#    'Closed'),
#   'count': 12},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Assignment',
#    'Closed',
#    'Status Change'),
#   'count': 12},
#  {'variant': ('Mail to Customer',
#    'Assignment',
#    'Closed',
#    'Status Change',
#    'Open'),
#   'count': 12},
#  {'variant': ('Closed', 'Status Change', 'Update', 'Open'), 'count': 12},
#  {'variant': ('Closed',
#    'Status Change',
#    'Mail to Customer',
#    'Open',
#    'Assignment'),
#   'count': 12},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Assignment',
#    'Open'),
#   'count': 12},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 12},
#  {'variant': ('Closed', 'Assignment', 'Caused By CI', 'Open', 'Status Change'),
#   'count': 12},
#  {'variant': ('Caused By CI', 'Open', 'Status Change', 'Closed', 'Assignment'),
#   'count': 12},
#  {'variant': ('Caused By CI', 'Open', 'Assignment', 'Status Change', 'Closed'),
#   'count': 12},
#  {'variant': ('Caused By CI', 'Closed', 'Quality Indicator', 'Open'),
#   'count': 12},
#  {'variant': ('Assignment',
#    'Mail to Customer',
#    'Open',
#    'Closed',
#    'Status Change'),
#   'count': 12},
#  {'variant': ('Assignment', 'Closed', 'Status Change', 'Caused By CI', 'Open'),
#   'count': 12},
#  {'variant': ('Assignment',
#    'Closed',
#    'Mail to Customer',
#    'Status Change',
#    'Open'),
#   'count': 12},
#  {'variant': ('Assignment', 'Caused By CI', 'Open', 'Status Change', 'Closed'),
#   'count': 12},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 11},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 11},
#  {'variant': ('Operator Update', 'Open', 'Closed', 'Caused By CI'),
#   'count': 11},
#  {'variant': ('Operator Update',
#    'Open',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 11},
#  {'variant': ('Operator Update',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 11},
#  {'variant': ('Open', 'Update', 'Closed', 'Caused By CI'), 'count': 11},
#  {'variant': ('Open',
#    'Operator Update',
#    'Status Change',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 11},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Status Change',
#    'Closed',
#    'Assignment'),
#   'count': 11},
#  {'variant': ('Open',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed'),
#   'count': 11},
#  {'variant': ('Open',
#    'Assignment',
#    'Closed',
#    'Status Change',
#    'Mail to Customer'),
#   'count': 11},
#  {'variant': ('Open',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed'),
#   'count': 11},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 11},
#  {'variant': ('Closed', 'Status Change', 'Open', 'Caused By CI', 'Assignment'),
#   'count': 11},
#  {'variant': ('Closed', 'Quality Indicator', 'Caused By CI', 'Open'),
#   'count': 11},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Operator Update',
#    'Status Change',
#    'Assignment'),
#   'count': 11},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Assignment',
#    'Operator Update',
#    'Open'),
#   'count': 11},
#  {'variant': ('Closed', 'Assignment', 'Status Change', 'Open'), 'count': 11},
#  {'variant': ('Closed', 'Assignment', 'Open', 'Status Change', 'Caused By CI'),
#   'count': 11},
#  {'variant': ('Caused By CI', 'Quality Indicator Fixed', 'Open', 'Closed'),
#   'count': 11},
#  {'variant': ('Caused By CI', 'Closed', 'Reassignment', 'Open'), 'count': 11},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Assignment',
#    'Open'),
#   'count': 11},
#  {'variant': ('Caused By CI', 'Closed', 'Operator Update', 'Open'),
#   'count': 11},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Closed',
#    'Open',
#    'Mail to Customer'),
#   'count': 11},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Closed',
#    'Mail to Customer',
#    'Open'),
#   'count': 11},
#  {'variant': ('Assignment',
#    'Operator Update',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 11},
#  {'variant': ('Assignment', 'Caused By CI', 'Open', 'Closed', 'Status Change'),
#   'count': 11},
#  {'variant': ('Status Change',
#    'Open',
#    'Mail to Customer',
#    'Assignment',
#    'Closed'),
#   'count': 10},
#  {'variant': ('Status Change',
#    'Mail to Customer',
#    'Assignment',
#    'Open',
#    'Closed'),
#   'count': 10},
#  {'variant': ('Status Change', 'Closed', 'Assignment', 'Open'), 'count': 10},
#  {'variant': ('Status Change', 'Assignment', 'Caused By CI', 'Open', 'Closed'),
#   'count': 10},
#  {'variant': ('Quality Indicator Fixed', 'Closed', 'Open', 'Caused By CI'),
#   'count': 10},
#  {'variant': ('Open',
#    'Status Change',
#    'Closed',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed'),
#   'count': 10},
#  {'variant': ('Open', 'Status Change', 'Assignment', 'Closed'), 'count': 10},
#  {'variant': ('Open',
#    'Operator Update',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 10},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Assignment',
#    'Status Change',
#    'Closed'),
#   'count': 10},
#  {'variant': ('Open', 'Closed', 'Update'), 'count': 10},
#  {'variant': ('Open',
#    'Closed',
#    'Status Change',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Open', 'Closed', 'Quality Indicator', 'Caused By CI'),
#   'count': 10},
#  {'variant': ('Open', 'Closed', 'Assignment', 'Caused By CI', 'Status Change'),
#   'count': 10},
#  {'variant': ('Open',
#    'Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Open', 'Caused By CI', 'Assignment', 'Status Change', 'Closed'),
#   'count': 10},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Operator Update',
#    'Closed',
#    'Caused By CI'),
#   'count': 10},
#  {'variant': ('Open', 'Assignment', 'Closed', 'Status Change', 'Caused By CI'),
#   'count': 10},
#  {'variant': ('Mail to Customer',
#    'Closed',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Closed', 'Status Change', 'Assignment', 'Caused By CI', 'Open'),
#   'count': 10},
#  {'variant': ('Closed',
#    'Open',
#    'Assignment',
#    'Mail to Customer',
#    'Status Change'),
#   'count': 10},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Assignment',
#    'Open'),
#   'count': 10},
#  {'variant': ('Closed', 'Assignment', 'Open', 'Caused By CI', 'Status Change'),
#   'count': 10},
#  {'variant': ('Closed',
#    'Assignment',
#    'Mail to Customer',
#    'Status Change',
#    'Open'),
#   'count': 10},
#  {'variant': ('Caused By CI', 'Status Change', 'Assignment', 'Closed', 'Open'),
#   'count': 10},
#  {'variant': ('Caused By CI', 'Open', 'Closed', 'Quality Indicator Fixed'),
#   'count': 10},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Open',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Open',
#    'Assignment'),
#   'count': 10},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Open'),
#   'count': 10},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Mail to Customer',
#    'Closed',
#    'Open'),
#   'count': 10},
#  {'variant': ('Assignment', 'Status Change', 'Closed', 'Open'), 'count': 10},
#  {'variant': ('Assignment', 'Open', 'Closed', 'Status Change', 'Caused By CI'),
#   'count': 10},
#  {'variant': ('Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed'),
#   'count': 10},
#  {'variant': ('Assignment',
#    'Mail to Customer',
#    'Open',
#    'Status Change',
#    'Closed'),
#   'count': 10},
#  {'variant': ('Assignment', 'Closed', 'Open', 'Status Change'), 'count': 10},
#  {'variant': ('Status Change',
#    'Open',
#    'Assignment',
#    'Closed',
#    'Mail to Customer'),
#   'count': 9},
#  {'variant': ('Status Change',
#    'Closed',
#    'Open',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 9},
#  {'variant': ('Status Change', 'Closed', 'Open', 'Assignment', 'Caused By CI'),
#   'count': 9},
#  {'variant': ('Status Change',
#    'Closed',
#    'Mail to Customer',
#    'Assignment',
#    'Open'),
#   'count': 9},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Open',
#    'Assignment',
#    'Status Change'),
#   'count': 9},
#  {'variant': ('Quality Indicator', 'Closed', 'Open', 'Caused By CI'),
#   'count': 9},
#  {'variant': ('Open', 'Update', 'Closed', 'Assignment'), 'count': 9},
#  {'variant': ('Open',
#    'Status Change',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment'),
#   'count': 9},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Mail to Customer'),
#   'count': 9},
#  {'variant': ('Open', 'Reassignment', 'Caused By CI', 'Closed'), 'count': 9},
#  {'variant': ('Open',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI',
#    'Assignment'),
#   'count': 9},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Assignment',
#    'Closed',
#    'Status Change'),
#   'count': 9},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Status Change',
#    'Assignment'),
#   'count': 9},
#  {'variant': ('Open',
#    'Closed',
#    'Assignment',
#    'Status Change',
#    'Mail to Customer'),
#   'count': 9},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Quality Indicator'),
#   'count': 9},
#  {'variant': ('Open',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI'),
#   'count': 9},
#  {'variant': ('Open',
#    'Assignment',
#    'Operator Update',
#    'Status Change',
#    'Caused By CI',
#    'Closed'),
#   'count': 9},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 9},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Closed'),
#   'count': 9},
#  {'variant': ('Mail to Customer',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 9},
#  {'variant': ('Mail to Customer',
#    'Closed',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 9},
#  {'variant': ('Mail to Customer',
#    'Assignment',
#    'Status Change',
#    'Open',
#    'Closed'),
#   'count': 9},
#  {'variant': ('Closed', 'Update', 'Status Change', 'Open'), 'count': 9},
#  {'variant': ('Closed', 'Open', 'Caused By CI', 'Quality Indicator Fixed'),
#   'count': 9},
#  {'variant': ('Closed', 'Open', 'Assignment', 'Caused By CI', 'Status Change'),
#   'count': 9},
#  {'variant': ('Closed',
#    'Mail to Customer',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 9},
#  {'variant': ('Closed',
#    'Mail to Customer',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 9},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment',
#    'Operator Update'),
#   'count': 9},
#  {'variant': ('Closed', 'Assignment', 'Resolved', 'Open'), 'count': 9},
#  {'variant': ('Caused By CI', 'Status Change', 'Assignment', 'Open', 'Closed'),
#   'count': 9},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 9},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Operator Update'),
#   'count': 9},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Assignment',
#    'Operator Update',
#    'Open'),
#   'count': 9},
#  {'variant': ('Caused By CI', 'Assignment', 'Open', 'Status Change', 'Closed'),
#   'count': 9},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Operator Update',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 9},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Open'),
#   'count': 9},
#  {'variant': ('Assignment', 'Open', 'Caused By CI', 'Status Change', 'Closed'),
#   'count': 9},
#  {'variant': ('Assignment',
#    'Open',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Closed'),
#   'count': 9},
#  {'variant': ('Assignment',
#    'Mail to Customer',
#    'Closed',
#    'Status Change',
#    'Open'),
#   'count': 9},
#  {'variant': ('Status Change',
#    'Mail to Customer',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Resolved', 'Closed', 'Assignment', 'Open'), 'count': 8},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Operator Update', 'Caused By CI', 'Closed', 'Open'),
#   'count': 8},
#  {'variant': ('Open', 'Status Change', 'Update', 'Closed'), 'count': 8},
#  {'variant': ('Open', 'Status Change', 'Closed', 'Assignment'), 'count': 8},
#  {'variant': ('Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Status Change'),
#   'count': 8},
#  {'variant': ('Open',
#    'Closed',
#    'Mail to Customer',
#    'Status Change',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Open',
#    'Closed',
#    'External update',
#    'External update',
#    'Status Change',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Open',
#    'Closed',
#    'Assignment',
#    'Mail to Customer',
#    'Status Change'),
#   'count': 8},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Mail to Customer',
#    'Closed'),
#   'count': 8},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Mail to Customer'),
#   'count': 8},
#  {'variant': ('Mail to Customer',
#    'Assignment',
#    'Open',
#    'Status Change',
#    'Closed'),
#   'count': 8},
#  {'variant': ('Closed', 'Status Change', 'Open', 'Assignment', 'Caused By CI'),
#   'count': 8},
#  {'variant': ('Closed',
#    'Status Change',
#    'Mail to Customer',
#    'Assignment',
#    'Open'),
#   'count': 8},
#  {'variant': ('Closed', 'Status Change', 'Assignment', 'Open', 'Caused By CI'),
#   'count': 8},
#  {'variant': ('Closed',
#    'Status Change',
#    'Assignment',
#    'Mail to Customer',
#    'Open'),
#   'count': 8},
#  {'variant': ('Closed', 'Resolved', 'Open', 'Assignment'), 'count': 8},
#  {'variant': ('Closed',
#    'Pending vendor',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 8},
#  {'variant': ('Closed', 'Open', 'Caused By CI', 'Assignment', 'Status Change'),
#   'count': 8},
#  {'variant': ('Closed', 'Caused By CI', 'Reassignment', 'Open'), 'count': 8},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 8},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Open',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Operator Update'),
#   'count': 8},
#  {'variant': ('Closed', 'Assignment', 'Operator Update', 'Open'), 'count': 8},
#  {'variant': ('Caused By CI', 'Status Change', 'Open', 'Assignment', 'Closed'),
#   'count': 8},
#  {'variant': ('Caused By CI',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 8},
#  {'variant': ('Caused By CI', 'Quality Indicator', 'Open', 'Closed'),
#   'count': 8},
#  {'variant': ('Caused By CI', 'Closed', 'Update', 'Open'), 'count': 8},
#  {'variant': ('Caused By CI', 'Assignment', 'Status Change', 'Open', 'Closed'),
#   'count': 8},
#  {'variant': ('Caused By CI', 'Assignment', 'Open', 'Closed', 'Status Change'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Mail to Customer',
#    'Open',
#    'Closed'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Open',
#    'Status Change',
#    'Pending vendor',
#    'Closed'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Open',
#    'Status Change',
#    'Closed',
#    'Mail to Customer'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Open',
#    'Operator Update',
#    'Closed',
#    'Caused By CI'),
#   'count': 8},
#  {'variant': ('Assignment',
#    'Closed',
#    'Status Change',
#    'Mail to Customer',
#    'Open'),
#   'count': 8},
#  {'variant': ('Status Change',
#    'Operator Update',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Open',
#    'Caused By CI',
#    'Closed',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Open',
#    'Assignment',
#    'Mail to Customer',
#    'Closed'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Mail to Customer',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Closed',
#    'Assignment',
#    'Mail to Customer',
#    'Open'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed'),
#   'count': 7},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Open'),
#   'count': 7},
#  {'variant': ('Reassignment', 'Open', 'Caused By CI', 'Closed'), 'count': 7},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 7},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 7},
#  {'variant': ('Quality Indicator',
#    'Caused By CI',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 7},
#  {'variant': ('Quality Indicator',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Open'),
#   'count': 7},
#  {'variant': ('Operator Update',
#    'Open',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 7},
#  {'variant': ('Operator Update',
#    'Assignment',
#    'Status Change',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 7},
#  {'variant': ('Operator Update',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 7},
#  {'variant': ('Operator Update',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 7},
#  {'variant': ('Open',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Open', 'Operator Update', 'Closed', 'Caused By CI'),
#   'count': 7},
#  {'variant': ('Open', 'Operator Update', 'Assignment', 'Closed'), 'count': 7},
#  {'variant': ('Open',
#    'Closed',
#    'Pending vendor',
#    'Assignment',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Open',
#    'Closed',
#    'Operator Update',
#    'Caused By CI',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Quality Indicator'),
#   'count': 7},
#  {'variant': ('Open', 'Caused By CI', 'Closed', 'Caused By CI'), 'count': 7},
#  {'variant': ('Open', 'Assignment', 'Status Change', 'Closed'), 'count': 7},
#  {'variant': ('Open',
#    'Assignment',
#    'Mail to Customer',
#    'Status Change',
#    'Closed'),
#   'count': 7},
#  {'variant': ('Open',
#    'Assignment',
#    'Closed',
#    'Mail to Customer',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Mail to Customer',
#    'Open',
#    'Closed',
#    'Assignment',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Mail to Customer',
#    'Closed',
#    'Assignment',
#    'Open',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Mail to Customer',
#    'Assignment',
#    'Closed',
#    'Open',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Closed', 'Update', 'Open', 'Status Change'), 'count': 7},
#  {'variant': ('Closed',
#    'Status Change',
#    'Open',
#    'Mail to Customer',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Closed', 'Status Change', 'Assignment', 'Open'), 'count': 7},
#  {'variant': ('Closed', 'Resolved', 'Assignment', 'Open'), 'count': 7},
#  {'variant': ('Closed', 'Quality Indicator Fixed', 'Open', 'Caused By CI'),
#   'count': 7},
#  {'variant': ('Closed', 'Quality Indicator', 'Open', 'Caused By CI'),
#   'count': 7},
#  {'variant': ('Closed', 'Open', 'Status Change', 'Update'), 'count': 7},
#  {'variant': ('Closed', 'Open', 'Caused By CI', 'Quality Indicator'),
#   'count': 7},
#  {'variant': ('Closed', 'Open', 'Assignment', 'Status Change', 'Caused By CI'),
#   'count': 7},
#  {'variant': ('Closed',
#    'Mail to Customer',
#    'Assignment',
#    'Open',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Closed', 'Caused By CI', 'Update', 'Open'), 'count': 7},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Status Change',
#    'Operator Update',
#    'Open',
#    'Assignment'),
#   'count': 7},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 7},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Assignment', 'Update'),
#   'count': 7},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Assignment',
#    'Status Change',
#    'Open',
#    'Operator Update'),
#   'count': 7},
#  {'variant': ('Closed',
#    'Assignment',
#    'Pending vendor',
#    'Status Change',
#    'Open'),
#   'count': 7},
#  {'variant': ('Caused By CI',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Assignment',
#    'Open'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Open',
#    'Mail to Customer',
#    'Closed'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Operator Update',
#    'Caused By CI',
#    'Closed',
#    'Open'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Open',
#    'Mail to Customer',
#    'Closed',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Mail to Customer'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Open',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed',
#    'Quality Indicator Fixed'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Status Change'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Closed',
#    'Pending vendor',
#    'Status Change',
#    'Open'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Closed',
#    'Caused By CI',
#    'Status Change',
#    'Operator Update',
#    'Open'),
#   'count': 7},
#  {'variant': ('Assignment',
#    'Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Open'),
#   'count': 7},
#  {'variant': ('Update', 'Reassignment', 'Open', 'Caused By CI', 'Closed'),
#   'count': 6},
#  {'variant': ('Update', 'Open', 'Status Change', 'Closed'), 'count': 6},
#  {'variant': ('Status Change',
#    'Open',
#    'Mail to Customer',
#    'Closed',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Status Change',
#    'Mail to Customer',
#    'Open',
#    'Assignment',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Status Change',
#    'Closed',
#    'Assignment',
#    'Open',
#    'Mail to Customer'),
#   'count': 6},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Quality Indicator',
#    'Closed',
#    'Open'),
#   'count': 6},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Pending vendor',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Status Change', 'Assignment', 'Open', 'Closed'), 'count': 6},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator',
#    'Open'),
#   'count': 6},
#  {'variant': ('Resolved', 'Closed', 'Open', 'Assignment'), 'count': 6},
#  {'variant': ('Reassignment', 'Open', 'Closed', 'Caused By CI'), 'count': 6},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Open'),
#   'count': 6},
#  {'variant': ('Quality Indicator',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Quality Indicator', 'Caused By CI', 'Open', 'Closed'),
#   'count': 6},
#  {'variant': ('Pending vendor',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 6},
#  {'variant': ('Operator Update',
#    'Reassignment',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 6},
#  {'variant': ('Operator Update',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Closed',
#    'Open'),
#   'count': 6},
#  {'variant': ('Open', 'Update', 'Status Change', 'Assignment', 'Closed'),
#   'count': 6},
#  {'variant': ('Open', 'Update', 'Caused By CI', 'Closed'), 'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Pending vendor',
#    'External Vendor Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Operator Update',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Operator Update',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Mail to Customer',
#    'Assignment',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Status Change',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Assignment',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open', 'Quality Indicator', 'Closed', 'Caused By CI'),
#   'count': 6},
#  {'variant': ('Open',
#    'Operator Update',
#    'Closed',
#    'Caused By CI',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Open',
#    'Operator Update',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Operator Update',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Mail to Customer',
#    'Status Change',
#    'Assignment',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Quality Indicator'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Mail to Customer',
#    'Assignment',
#    'Status Change'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Assignment',
#    'Status Change'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Operator Update',
#    'Status Change',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Open',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Status Change',
#    'Operator Update'),
#   'count': 6},
#  {'variant': ('Open',
#    'Caused By CI',
#    'Closed',
#    'Operator Update',
#    'Status Change',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Pending vendor',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Quality Indicator Fixed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator'),
#   'count': 6},
#  {'variant': ('Open',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Quality Indicator',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Open',
#    'Assignment',
#    'Closed',
#    'Quality Indicator',
#    'Caused By CI'),
#   'count': 6},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Open',
#    'Assignment',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Mail to Customer',
#    'Status Change',
#    'Caused By CI',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed', 'Status Change', 'Open', 'Update'), 'count': 6},
#  {'variant': ('Closed',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Mail to Customer'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Operator Update',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 6},
#  {'variant': ('Closed', 'Operator Update', 'Assignment', 'Open'), 'count': 6},
#  {'variant': ('Closed', 'Open', 'Update', 'Status Change'), 'count': 6},
#  {'variant': ('Closed', 'Open', 'Operator Update', 'Assignment'), 'count': 6},
#  {'variant': ('Closed',
#    'Mail to Customer',
#    'Status Change',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Mail to Customer',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Open',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Status Change',
#    'Operator Update',
#    'Assignment'),
#   'count': 6},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Quality Indicator'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Open',
#    'Operator Update',
#    'Assignment',
#    'Status Change'),
#   'count': 6},
#  {'variant': ('Closed', 'Caused By CI', 'Open', 'Description Update'),
#   'count': 6},
#  {'variant': ('Closed',
#    'Caused By CI',
#    'Assignment',
#    'Open',
#    'Status Change',
#    'Operator Update'),
#   'count': 6},
#  {'variant': ('Closed', 'Caused By CI', 'Assignment', 'Open', 'Reassignment'),
#   'count': 6},
#  {'variant': ('Closed', 'Assignment', 'Update', 'Status Change', 'Open'),
#   'count': 6},
#  {'variant': ('Closed', 'Assignment', 'Status Change', 'Open', 'Caused By CI'),
#   'count': 6},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Open',
#    'Reassignment',
#    'Operator Update'),
#   'count': 6},
#  {'variant': ('Caused By CI', 'Closed', 'Open', 'Reassignment'), 'count': 6},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Assignment',
#    'Operator Update',
#    'Status Change',
#    'Open'),
#   'count': 6},
#  {'variant': ('Caused By CI',
#    'Closed',
#    'Assignment',
#    'Open',
#    'Operator Update'),
#   'count': 6},
#  {'variant': ('Assignment',
#    'Status Change',
#    'Open',
#    'Operator Update',
#    'Closed'),
#   'count': 6},
#  {'variant': ('Assignment',
# ...
#    'Open',
#    'Mail to Customer',
#    'Status Change',
#    'Closed'),
#   'count': 4},
#  {'variant': ('Assignment', 'Open', 'Closed', 'Operator Update'), 'count': 4},
#  {'variant': ('Assignment',
#    'Mail to Customer',
#    'Status Change',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 4},
#  {'variant': ('Assignment', 'Closed', 'Status Change', 'Update', 'Open'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Status Change',
#    'Operator Update',
#    'Open'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Status Change',
#    'Open',
#    'Mail to Customer'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Open'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Open',
#    'Mail to Customer',
#    'Status Change'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'External update',
#    'External update',
#    'Open',
#    'Status Change'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Caused By CI',
#    'Status Change',
#    'Update',
#    'Open'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Closed',
#    'Caused By CI',
#    'Quality Indicator',
#    'Status Change',
#    'Open'),
#   'count': 4},
#  {'variant': ('Assignment',
#    'Caused By CI',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Quality Indicator Fixed'),
#   'count': 4},
#  {'variant': ('Assignment', 'Caused By CI', 'Closed', 'Open', 'Update'),
#   'count': 4},
#  {'variant': ('Update', 'Status Change', 'Open', 'Assignment', 'Closed'),
#   'count': 3},
#  {'variant': ('Update',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Update', 'Open', 'Status Change', 'Assignment', 'Closed'),
#   'count': 3},
#  {'variant': ('Update',
#    'Open',
#    'Status Change',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Update', 'Open', 'Closed', 'Status Change', 'Assignment'),
#   'count': 3},
#  {'variant': ('Update', 'Open', 'Closed', 'Assignment'), 'count': 3},
#  {'variant': ('Update', 'Open', 'Caused By CI', 'Closed'), 'count': 3},
#  {'variant': ('Update', 'Closed', 'Reassignment', 'Open'), 'count': 3},
#  {'variant': ('Update', 'Closed', 'Caused By CI', 'Reassignment', 'Open'),
#   'count': 3},
#  {'variant': ('Update', 'Closed', 'Assignment', 'Status Change', 'Open'),
#   'count': 3},
#  {'variant': ('Update', 'Caused By CI', 'Closed', 'Open', 'Reassignment'),
#   'count': 3},
#  {'variant': ('Update', 'Assignment', 'Status Change', 'Open', 'Closed'),
#   'count': 3},
#  {'variant': ('Update', 'Assignment', 'Open', 'Closed'), 'count': 3},
#  {'variant': ('Update', 'Assignment', 'Open', 'Caused By CI', 'Closed'),
#   'count': 3},
#  {'variant': ('Status Change', 'Update', 'Open', 'Assignment', 'Closed'),
#   'count': 3},
#  {'variant': ('Status Change', 'Update', 'Assignment', 'Closed', 'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Quality Indicator Fixed',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Quality Indicator',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Quality Indicator',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Pending vendor',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Pending vendor',
#    'External Vendor Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Operator Update',
#    'Open',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Operator Update',
#    'Closed',
#    'Open',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Operator Update',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Pending vendor',
#    'Assignment',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Operator Update',
#    'Caused By CI',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 3},
#  {'variant': ('Status Change', 'Open', 'Closed', 'Assignment', 'Update'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Assignment',
#    'Operator Update',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Open',
#    'Assignment',
#    'Closed',
#    'Quality Indicator Fixed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'External update',
#    'Closed',
#    'External update',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change', 'Closed', 'Update', 'Open', 'Assignment'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Closed',
#    'Mail to Customer',
#    'Caused By CI',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment',
#    'Mail to Customer'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Closed',
#    'Assignment',
#    'Caused By CI',
#    'Quality Indicator',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Caused By CI',
#    'Closed',
#    'Mail to Customer',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Caused By CI',
#    'Assignment',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change', 'Assignment', 'Update', 'Closed', 'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Open',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Mail to Customer',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Quality Indicator Fixed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Quality Indicator Fixed',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed',
#    'Quality Indicator Fixed'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'External update',
#    'Open',
#    'Closed',
#    'External update'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'External update',
#    'External update',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Communication with customer',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Quality Indicator Fixed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Quality Indicator',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Quality Indicator',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Closed',
#    'Open',
#    'External update',
#    'External update'),
#   'count': 3},
#  {'variant': ('Status Change',
#    'Assignment',
#    'Caused By CI',
#    'Quality Indicator',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Update', 'Closed', 'Open'), 'count': 3},
#  {'variant': ('Reassignment',
#    'Update',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Update',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Status Change',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Open',
#    'Closed',
#    'Reassignment',
#    'Operator Update'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Open', 'Closed', 'Caused By CI', 'Assignment'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Closed', 'Update', 'Open', 'Caused By CI'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Closed', 'Caused By CI', 'Update', 'Open'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Closed', 'Caused By CI', 'Open'), 'count': 3},
#  {'variant': ('Reassignment',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Open',
#    'Update'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Assignment',
#    'Status Change',
#    'Open',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Reassignment', 'Assignment', 'Open', 'Closed', 'Caused By CI'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Update',
#    'Open'),
#   'count': 3},
#  {'variant': ('Reassignment',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Update'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Status Change',
#    'Caused By CI',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Status Change'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Caused By CI',
#    'Assignment',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Open',
#    'Assignment',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Quality Indicator Set',
#    'Mail to Customer',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Open',
#    'Assignment',
#    'Status Change'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Closed',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Open',
#    'Closed',
#    'Assignment',
#    'Status Change'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Caused By CI',
#    'Closed',
#    'Open',
#    'Status Change',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Assignment',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Quality Indicator Fixed',
#    'Assignment',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Open',
#    'Closed',
#    'Status Change',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Closed',
#    'Operator Update',
#    'Status Change',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Closed',
#    'Caused By CI',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Caused By CI',
#    'Open',
#    'Status Change',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Open',
#    'Status Change'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Caused By CI',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Quality Indicator',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Pending vendor',
#    'Status Change',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Pending vendor',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Pending vendor',
#    'Closed',
#    'Assignment',
#    'Open',
#    'Status Change'),
#   'count': 3},
#  {'variant': ('Pending vendor',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Open',
#    'Operator Update',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Open',
#    'Closed',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Closed',
#    'Caused By CI',
#    'Open',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Status Change',
#    'Caused By CI',
#    'Assignment',
#    'Closed',
#    'Open'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Reassignment',
#    'Open',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Open',
#    'Closed',
#    'Caused By CI',
#    'Reassignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Open',
#    'Closed',
#    'Caused By CI',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Open',
#    'Closed',
#    'Assignment',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Open',
#    'Assignment',
#    'Status Change',
#    'Caused By CI',
#    'Closed'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Closed',
#    'Status Change',
#    'Assignment',
#    'Caused By CI',
#    'Open'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Closed',
#    'Open',
#    'Caused By CI',
#    'Reassignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Closed',
#    'Caused By CI',
#    'Status Change',
#    'Open',
#    'Assignment'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Caused By CI',
#    'Status Change',
#    'Closed',
#    'Assignment',
#    'Open'),
#   'count': 3},
#  {'variant': ('Operator Update',
#    'Caused By CI',
#    'Closed',
#    'Assignment',
#    'Status Change',
#    'Open'),
#   'count': 3},
#  {'variant': ('Open', 'Update', 'Status Change', 'Closed', 'Assignment'),
#   'count': 3},
#  {'variant': ('Open',
#    'Update',
#    'Status Change',
#    'Assignment',
#    'Closed',
#    'Caused By CI'),
#   'count': 3},
#  {'variant': ('Open', 'Update', 'Closed', 'Update', 'Status Change'),
#   'count': 3},
#  {'variant': ('Open', 'Update', 'Caused By CI', 'Closed', 'Reassignment'),
#   'count': 3},
#  {'variant': ('Open', 'Update', 'Assignment', 'Closed', 'Caused By CI'),
#   'count': 3},
#  {'variant': ('Open', 'Status Change', 'Update', 'Closed', 'Update'),
#   'count': 3},
#  ...]

# %%
max_count = max(variants_count, key=lambda x: x['count'])
print(max_count)
# Out:
# {'variant': ('Open', 'Closed', 'Caused By CI'), 'count': 716}

# %%
#1 минимальное и максимальное количество событий в одном случае
print("min = ", min(log_csv.groupby('case:concept:name').count()['concept:name']))
print("max = ", max(log_csv.groupby('case:concept:name').count()['concept:name']))
# Out:
# min =  1
# max =  178

# %%
#4 На какой инцендент потратили меньше всего времени, а какой больше?

min_caselength = log_csv.loc[log_csv['caselength'].idxmin()]['case:concept:name']
print("потратили больше всего времени на инцендент: ", min_caselength, " - ", min(log_csv['caselength']) )

max_caselength = log_csv.loc[log_csv['caselength'].idxmax()]['case:concept:name']
print("потратили больше всего времени на инцендент: ", max_caselength," - ", max(log_csv['caselength']) )
# Out:
# потратили больше всего времени на инцендент:  IM0000023  -  0 days 00:00:00
# потратили больше всего времени на инцендент:  IM0000046  -  699 days 00:58:57

# %%
log_csv[log_csv['case:concept:name'] == 'IM0000023']
# Out:
#     case:concept:name          time:timestamp IncidentActivity_Number  \
# 194         IM0000023 2013-12-12 10:24:45.100             001A6165328
# 195         IM0000023 2013-12-12 10:24:45.000             001A6165329
#
#      concept:name org:resource  KM number Interaction ID             caseend  \
# 194        Closed     TEAM0006  KM0000670      SD0000045 2013-12-12 10:24:45
# 195  Caused By CI     TEAM0006  KM0000670      SD0000045 2013-12-12 10:24:45
#
#               casestart relativetime  relativetime_s  relativedays caselength
# 194 2013-12-12 10:24:45       0 days               0             0     0 days
# 195 2013-12-12 10:24:45       0 days               0             0     0 days

# %%
log_csv[log_csv['case:concept:name'] == 'IM0000046']
# Out:
#     case:concept:name          time:timestamp IncidentActivity_Number  \
# 432         IM0000046 2013-01-02 12:43:21.000             001A3891951
# 433         IM0000046 2013-05-02 10:32:36.000             001A3912977
# 434         IM0000046 2013-01-02 12:48:42.000             001A3894096
# 435         IM0000046 2013-01-02 12:48:42.000             001A3894097
# 436         IM0000046 2013-10-21 11:16:09.000             001A5729061
# 437         IM0000046 2013-05-02 08:22:56.000             001A3912543
# 438         IM0000046 2013-09-10 13:21:27.000             001A5652807
# 439         IM0000046 2013-09-10 13:21:27.000             001A5652808
# 440         IM0000046 2013-09-10 13:21:27.000             001A5652809
# 441         IM0000046 2013-01-02 12:48:42.000             001A3894095
# 442         IM0000046 2013-01-02 08:06:56.000             001A3886741
# 443         IM0000046 2013-01-02 08:06:56.000             001A3886742
# 444         IM0000046 2013-01-02 09:46:33.000             001A3890503
# 445         IM0000046 2013-12-07 12:00:59.000             001A5025695
# 446         IM0000046 2013-01-31 16:27:22.000             001A3886316
# 447         IM0000046 2014-12-02 08:52:38.000             001A6586105
# 448         IM0000046 2014-12-02 08:52:38.000             001A6586104
# 449         IM0000046 2014-12-02 09:05:53.000             001A6582776
# 450         IM0000046 2014-12-02 09:05:53.100             001A6582775
#
#         concept:name org:resource  KM number Interaction ID  \
# 432  Operator Update     TEAM0003  KM0000931      SD0000073
# 433  Operator Update     TEAM9999  KM0000931      SD0000073
# 434       Assignment     TEAM0003  KM0000931      SD0000073
# 435    Status Change     TEAM0003  KM0000931      SD0000073
# 436  Operator Update     TEAM0003  KM0000931      SD0000073
# 437  Operator Update     TEAM9999  KM0000931      SD0000073
# 438     Reassignment     TEAM0012  KM0000931      SD0000073
# 439       Assignment     TEAM0012  KM0000931      SD0000073
# 440  Operator Update     TEAM0012  KM0000931      SD0000073
# 441     Reassignment     TEAM0003  KM0000931      SD0000073
# 442       Assignment     TEAM0003  KM0000931      SD0000073
# 443    Status Change     TEAM0003  KM0000931      SD0000073
# 444    Status Change     TEAM0003  KM0000931      SD0000073
# 445           Update     TEAM9999  KM0000931      SD0000073
# 446             Open     TEAM0008  KM0000931      SD0000073
# 447           Update     TEAM0009  KM0000931      SD0000073
# 448     Reassignment     TEAM0009  KM0000931      SD0000073
# 449     Caused By CI     TEAM0171  KM0000931      SD0000073
# 450           Closed     TEAM0171  KM0000931      SD0000073
#
#                 caseend           casestart      relativetime  relativetime_s  \
# 432 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 04:36:25           16585
# 433 2014-12-02 09:05:53 2013-01-02 08:06:56 120 days 02:25:40        10376740
# 434 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 04:41:46           16906
# 435 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 04:41:46           16906
# 436 2014-12-02 09:05:53 2013-01-02 08:06:56 292 days 03:09:13        25240153
# 437 2014-12-02 09:05:53 2013-01-02 08:06:56 120 days 00:16:00        10368960
# 438 2014-12-02 09:05:53 2013-01-02 08:06:56 251 days 05:14:31        21705271
# 439 2014-12-02 09:05:53 2013-01-02 08:06:56 251 days 05:14:31        21705271
# 440 2014-12-02 09:05:53 2013-01-02 08:06:56 251 days 05:14:31        21705271
# 441 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 04:41:46           16906
# 442 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 00:00:00               0
# 443 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 00:00:00               0
# 444 2014-12-02 09:05:53 2013-01-02 08:06:56   0 days 01:39:37            5977
# 445 2014-12-02 09:05:53 2013-01-02 08:06:56 339 days 03:54:03        29303643
# 446 2014-12-02 09:05:53 2013-01-02 08:06:56  29 days 08:20:26         2535626
# 447 2014-12-02 09:05:53 2013-01-02 08:06:56 699 days 00:45:42        60396342
# 448 2014-12-02 09:05:53 2013-01-02 08:06:56 699 days 00:45:42        60396342
# 449 2014-12-02 09:05:53 2013-01-02 08:06:56 699 days 00:58:57        60397137
# 450 2014-12-02 09:05:53 2013-01-02 08:06:56 699 days 00:58:57        60397137
#
#      relativedays        caselength
# 432             0 699 days 00:58:57
# 433           120 699 days 00:58:57
# 434             0 699 days 00:58:57
# 435             0 699 days 00:58:57
# 436           292 699 days 00:58:57
# 437           120 699 days 00:58:57
# 438           251 699 days 00:58:57
# 439           251 699 days 00:58:57
# 440           251 699 days 00:58:57
# 441             0 699 days 00:58:57
# 442             0 699 days 00:58:57
# 443             0 699 days 00:58:57
# 444             0 699 days 00:58:57
# 445           339 699 days 00:58:57
# 446            29 699 days 00:58:57
# 447           699 699 days 00:58:57
# 448           699 699 days 00:58:57
# 449           699 699 days 00:58:57
# 450           699 699 days 00:58:57

# %%
#8 Есть ли группы, которые перегружены работой?
resource_counts = log_csv.groupby('org:resource')['concept:name'].count().reset_index(name='count')
resource_counts['%'] = resource_counts['count']/len(log_csv)*100
sorted_resource_counts = resource_counts.sort_values(by='%', ascending=False)

sorted_resource_counts
# Out:
#     org:resource  count          %
# 7       TEAM0008  81584  17.591213
# 38      TEAM0039  19199   4.139705
# 17      TEAM0018  17368   3.744903
# 30      TEAM0031  16414   3.539201
# 6       TEAM0007  15864   3.420609
# ..           ...    ...        ...
# 160     TEAM0161      2   0.000431
# 237     TEAM0238      1   0.000216
# 168     TEAM0169      1   0.000216
# 163     TEAM0164      1   0.000216
# 167     TEAM0168      1   0.000216
#
# [242 rows x 3 columns]

# %%
#Какие мероприятия (actions) непропорционально отнимают время у некоторых команд? Каково распределение событий среди команд?
# Сгруппированный журнал событий по группам и видам деятельности и среднее время, затраченное на каждое действие для каждой группы
grouped = log_csv.groupby(['org:resource', 'concept:name']).agg({'relativedays': 'mean'})

grouped
# Out:
#                                           relativedays
# org:resource concept:name
# TEAM0001     Analysis/Research               78.363636
#              Assignment                      72.845161
#              Caused By CI                    42.830645
#              Closed                          58.890625
#              Communication with customer     38.555556
# ...                                                ...
# TEAM9999     Update from customer            67.381963
#              Urgency Change                  36.809524
#              Vendor Reference                86.500000
#              Vendor Reference Change        183.000000
#              alert stage 1                  297.150442
#
# [2920 rows x 1 columns]

# %%
# общее среднее время, затраченное на каждое занятие всеми группами
overall_avg = log_csv.groupby('concept:name').agg({'relativedays': 'mean'})

overall_avg
# Out:
#                               relativedays
# concept:name
# Affected CI Change               43.326087
# Analysis/Research                74.248726
# Assignment                       49.637846
# Callback Request                 52.169811
# Caused By CI                     23.795184
# Closed                           29.033024
# Communication with customer      60.112504
# Communication with vendor        76.281520
# Contact Change                   40.062500
# Description Update               41.508054
# Dial-in                           1.500000
# External Vendor Assignment       44.978657
# External Vendor Reassignment     23.030303
# External update                   6.653321
# Impact Change                    48.054075
# Incident reproduction            48.521739
# Mail to Customer                 11.225977
# Notify By Change                 71.701068
# OO Response                      76.393939
# Open                             19.834828
# Operator Update                  56.637429
# Pending vendor                   43.252473
# Problem Closure                 126.700000
# Problem Workaround               81.935714
# Quality Indicator                22.564300
# Quality Indicator Fixed          26.960210
# Quality Indicator Set            23.553681
# Reassignment                     59.381839
# Referred                         35.862069
# Reopen                           69.647446
# Resolved                         33.327798
# Service Change                   39.402516
# Status Change                    40.084377
# Update                           56.003060
# Update from customer             79.841795
# Urgency Change                   46.951145
# Vendor Reference                 37.547256
# Vendor Reference Change          76.554688
# alert stage 1                   297.150442

# %%
#10 Какие события связаны с узкими местами и какие ресурсы задействованы? 
pd.pivot_table(log_csv,
               index=["concept:name", "org:resource"],
               values=["relativetime"],
               aggfunc=np.mean)
# Out:
#                                                     relativetime
# concept:name            org:resource
# Affected CI Change      TEAM9999      43 days 11:10:13.445652174
# Analysis/Research       TEAM0001      78 days 15:33:08.272727273
#                         TEAM0002        224 days 00:35:55.500000
#                         TEAM0003     112 days 13:12:30.419689120
#                         TEAM0004        128 days 23:50:21.750000
# ...                                                          ...
# Vendor Reference Change TEAM0188       3 days 12:28:07.777777777
#                         TEAM0190       1 days 00:45:36.333333333
#                         TEAM0211                 0 days 00:00:00
#                         TEAM9999               183 days 18:32:12
# alert stage 1           TEAM9999     297 days 09:14:40.663716816
#
# [2920 rows x 1 columns]

# %% [markdown]
# Модели данных

# %%
from pm4py.algo.discovery.alpha import algorithm as alpha_miner
parameters = {pn_visualizer.Variants.FREQUENCY.value.Parameters.FORMAT: "png"}

net2, initial_marking2, final_marking2 = alpha_miner.apply(event_log)

# %%
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator
from pm4py.algo.evaluation.replay_fitness import algorithm as replay_fitness_evaluator
from pm4py.algo.evaluation.precision import algorithm as precision_evaluator
from pm4py.algo.evaluation.generalization import algorithm as generalization_evaluator
from pm4py.visualization.petri_net import visualizer as pn_visualizer

# %%
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator
simplicity2 = simplicity_evaluator.apply(net2)
print(f"Простота равна: {simplicity2}\n")

fitness2 = replay_fitness_evaluator.apply(
    event_log, 
    net2, 
    initial_marking2, 
    final_marking2, 
    variant=replay_fitness_evaluator.Variants.TOKEN_BASED,
)
print(f"Пригодность воспроизведения, используя метод на основе токенов, равна {fitness2}\n")
# Out:
# Простота равна: 0.38888888888888884
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]
# Пригодность воспроизведения, используя метод на основе токенов, равна {'perc_fit_traces': 0.0021660493426040243, 'average_trace_fitness': 0.25681588663027854, 'log_fitness': 0.1810719525986655, 'percentage_of_fitting_traces': 0.0021660493426040243}

# %%
gviz = pn_visualizer.apply(net2, initial_marking2, final_marking2,
                           parameters=parameters,
                           variant=pn_visualizer.Variants.FREQUENCY,
                           log=event_log)
pn_visualizer.view(gviz)
# Out:
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]

# %%
prec = precision_evaluator.apply(
    event_log, 
    net2, 
    initial_marking2, 
    final_marking2, 
    variant=precision_evaluator.Variants.ETCONFORMANCE_TOKEN,
)
print(f"\nТочность с помощью метода ETConformance равна {prec}\n")

gen = generalization_evaluator.apply(
    event_log, 
    net2, initial_marking2, 
    final_marking2,
)
print(f"\nОбобщение равно {gen}\n")
# Out:
# replaying log with TBR, completed variants ::   0%|          | 0/246971 [00:00<?, ?it/s]
# Точность с помощью метода ETConformance равна 0.8292668336790124
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]
# Обобщение равно 0.9279544801107015

# %%
from pm4py.algo.discovery.dfg import algorithm as dfg_graph
from pm4py.objects.conversion.dfg import converter as dfg_mining
parameters = {pn_visualizer.Variants.FREQUENCY.value.Parameters.FORMAT: "png"}

dfg = dfg_graph.apply(event_log)
net3, initial_marking3, final_marking3 = dfg_mining.apply(dfg)

# %%
simplicity3 = simplicity_evaluator.apply(net3)
print(f"Простота равна: {simplicity3}\n")

fitness3 = replay_fitness_evaluator.apply(
    event_log, 
    net3, 
    initial_marking3, 
    final_marking3, 
    variant=replay_fitness_evaluator.Variants.TOKEN_BASED,
)
print(f"Пригодность воспроизведения, используя метод на основе токенов, равна {fitness3}\n")

prec3 = precision_evaluator.apply(
    event_log, 
    net3, 
    initial_marking3, 
    final_marking3, 
    variant=precision_evaluator.Variants.ETCONFORMANCE_TOKEN,
)
print(f"\nТочность с помощью метода ETConformance равна {prec3}\n")

gen3 = generalization_evaluator.apply(
    event_log, 
    net3, 
    initial_marking3, 
    final_marking3,
)
print(f"\nОбобщение равно {gen3}\n")
# Out:
# Простота равна: 0.3536857781087118
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]
# Пригодность воспроизведения, используя метод на основе токенов, равна {'perc_fit_traces': 0.0, 'average_trace_fitness': 0.7431713342420392, 'log_fitness': 0.8189330593163171, 'percentage_of_fitting_traces': 0.0}
# replaying log with TBR, completed variants ::   0%|          | 0/246971 [00:00<?, ?it/s]
# Точность с помощью метода ETConformance равна 1.0
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]
# Обобщение равно 0.6532036132841841

# %%
gviz3 = pn_visualizer.apply(net3, initial_marking3, final_marking3,
                           parameters=parameters,
                           variant=pn_visualizer.Variants.FREQUENCY,
                           log=event_log)
pn_visualizer.view(gviz3)
# Out:
# replaying log with TBR, completed variants ::   0%|          | 0/31389 [00:00<?, ?it/s]
